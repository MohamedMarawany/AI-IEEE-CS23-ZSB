# %% [markdown]
# # Exploring Data with Visuals Quiz
# Use the space below to explore `powerplant_data_edited.csv` to answer the quiz questions below.

# %%
# Do your analysis and answer the following (use plots) (type your answers, do not just code stuff and runaway):

# What is the relationship between temperature and electrical output?
# A. Positive B. Negative C. No correlation    =====>> B. Negative
# Does the humidity variable appear to be normally distributed, if not, what is the ditribution?  ==>> Left Skewed
# Which variable appears to have the most outliers (plot all variables to answer this)? ====>> pressure

# %%
# import and load the data
import pandas as pd
# %matplotlib inline

df_powerplant = pd.read_csv('powerplant_data_edited.csv')
df_powerplant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   temperature     9568 non-null   float64
#  1   exhaust_vacuum  9568 non-null   float64
#  2   pressure        9568 non-null   float64
#  3   humidity        9568 non-null   float64
#  4   energy_output   9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
# explore the data
df_powerplant.hist(figsize=(8, 8))
# Out:
# array([[<Axes: title={'center': 'temperature'}>,
#         <Axes: title={'center': 'exhaust_vacuum'}>],
#        [<Axes: title={'center': 'pressure'}>,
#         <Axes: title={'center': 'humidity'}>],
#        [<Axes: title={'center': 'energy_output'}>, <Axes: >]],
#       dtype=object)

# %%
#df_powerplant['temperature'].hist()
df_powerplant['temperature'].plot(kind='hist');

# %%
# clean the data (check for any possible problem and fix it)
df_powerplant.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9568 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   temperature     9568 non-null   float64
#  1   exhaust_vacuum  9568 non-null   float64
#  2   pressure        9568 non-null   float64
#  3   humidity        9568 non-null   float64
#  4   energy_output   9568 non-null   float64
# dtypes: float64(5)
# memory usage: 373.9 KB

# %%
# plot the relationship between temperature and electrical output
pd.plotting.scatter_matrix(df_powerplant, figsize=(15, 15));
# what is the relationship between the temp and the enery_output (type your answer)?: B. Negative

# %%
# plot the distribution of humidity 
df_powerplant['humidity'].plot(kind='hist');
# what does the distribution look like ? : Left Skewed

# %%
# plot box plots for each variable
#temp_plot = df_powerplant['temperature'].plot(kind='box');
#exhaust_vacuum_plot = df_powerplant['exhaust_vacuum'].plot(kind='box');
#pressure_plot = df_powerplant['pressure'].plot(kind='box');
#humidity_plot = df_powerplant['humidity'].plot(kind='box');
#energy_output_plot = df_powerplant['energy_output'].plot(kind='box');

#df_powerplant.plot(kind='box');
boxplot = df_powerplant.boxplot()  

# type the variable name here: pressure
